# %%
text = "prasanth"

for i in text:
    print("character is -", i)
# Out:
# character is - p
# character is - r
# character is - a
# character is - s
# character is - a
# character is - n
# character is - t
# character is - h
